# %%
pip install --upgrade langchain
# Out:
# Requirement already satisfied: langchain in ./env/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in ./env/lib/python3.9/site-packages (from langchain) (2.7.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./env/lib/python3.9/site-packages (from langchain) (8.3.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./env/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.6 in ./env/lib/python3.9/site-packages (from langchain) (0.2.6)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./env/lib/python3.9/site-packages (from langchain) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in ./env/lib/python3.9/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./env/lib/python3.9/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./env/lib/python3.9/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in ./env/lib/python3.9/site-packages (from langchain) (0.2.1)
# Requirement already satisfied: PyYAML>=5.3 in ./env/lib/python3.9/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: requests<3,>=2 in ./env/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in ./env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in ./env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./env/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.6->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./env/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.6->langchain) (24.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./env/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.6->langchain) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./env/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./env/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: pydantic-core==2.18.4 in ./env/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (2.18.4)
# Requirement already satisfied: annotated-types>=0.4.0 in ./env/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3.2)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Users/cauhike/Documents/GitHub/rag/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Ollama (gemma)

# %%
import chromadb
client = chromadb.PersistentClient('../chroma/')
# chroma_client = chromadb.HttpClient(host="localhost", port=8000)
print(client.list_collections())
# Out:
# [Collection(name=address_pdf_multivector_summary_240611), Collection(name=test), Collection(name=address_ordinance_pdf), Collection(name=address_business_guide_pdf), Collection(name=address_regulation_pdf), Collection(name=address_law_pdf), Collection(name=address_pdf_multivector_240611), Collection(name=address_pdf_vanila_240611)]

# %%
## 컬렉션 삭제하기
client.delete_collection(
    name="test"
)

# %%
collection = client.get_or_create_collection(name="test")
collection.peek()
# Out:
# {'ids': [],
#  'embeddings': [],
#  'metadatas': [],
#  'documents': [],
#  'uris': None,
#  'data': None}

# %%
from langchain_community.document_loaders import PyMuPDFLoader
loader = PyMuPDFLoader("../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf")
pages = loader.load()
len(pages)
# Out:
# 20

# %%
pages = pages[:3]
pages
# Out:
# [Document(page_content='법제처                                                            1                                                       국가법령정보센터\n도로명주소법 시행규칙\n \n도로명주소법 시행규칙\n[시행 2022. 3. 30.] [행정안전부령 제324호, 2022. 3. 30., 타법개정]\n행정안전부 (주소생활공간과) 044-205-3567\n \n제1조(목적) 이 규칙은 「도로명주소법」 및 같은 법 시행령에서 위임된 사항과 그 시행에 필요한 사항을 규정함을 목적\n으로 한다.\n \n제2조(정의) 이 규칙에서 사용하는 용어의 뜻은 다음과 같다.\n1. “주된구간”이란 하나의 도로구간에서 종속구간을 제외한 도로구간을 말한다.\n2. “도로명관할구역”이란 「도로명주소법 시행령」(이하 “영”이라 한다) 제6조제1항제1호 및 제2호에 따른 행정구역\n을 말한다. 다만, 행정구역이 결정되지 않은 지역에서는 영 제6조제2항제1호가목 및 제2호나목에 따른 사업지역\n의 명칭을 말한다.\n3. “건물등관할구역”이란 영 제6조제1항제1호부터 제3호까지에 따른 행정구역을 말한다. 다만, 행정구역이 결정되\n지 않은 지역에서는 영 제6조제2항제1호가목 및 제2호나목에 따른 사업지역의 명칭을 말한다.\n \n제3조(기초번호의 부여 간격) 「도로명주소법」(이하 “법”이라 한다) 제2조제4호에서 “행정안전부령으로 정하는 간격”이\n란 20미터를 말한다. 다만, 다음 각 호의 도로에 대하여는 다음 각 호의 간격으로 한다.\n1. 「도로교통법」 제2조제3호에 따른 고속도로(이하 “고속도로”라 한다): 2킬로미터\n2. 건물번호의 가지번호가 두 자리 숫자 이상으로 부여될 수 있는 길 또는 해당 도로구간에서 분기되는 도로구간이\n없고, 가지번호를 이용한 건물번호를 부여하기 곤란한 길: 10미터\n3. 가지번호를 이용하여 건물번호를 부여하기 곤란한 종속구간: 10미터 이하의 일정한 간격\n4. 영 제3조제1항제3호에 따른 내부도로: 20미터 또는 도로명주소 및 사물주소의 부여 개수를 고려하여 정하는 간\n격\n \n제4조(기초조사 등) 「도로법」 제2조제5호에 따른 도로관리청은 법 제6조제2항에 따라 도로구역의 결정ㆍ변경 또는 폐\n지 사실을 해당 도로구역의 결정ㆍ변경 또는 폐지를 고시한 날부터 30일 이내에 다음 각 호의 사항을 포함하여 행정\n안전부장관, 특별시장ㆍ광역시장ㆍ특별자치시장ㆍ도지사 및 특별자치도지사(이하 “시ㆍ도지사”라 한다) 또는 시장\nㆍ군수ㆍ구청장(자치구의 구청장을 말한다. 이하 같다)에게 통보해야 한다.\n1. 「도로법」 제2조제6호에 따른 도로구역(이하 “도로구역”이라 한다)의 위치도 및 도로계획 평면도\n2. 도로구역의 결정ㆍ변경 또는 폐지 사유\n3. 「도로법」 제10조에 따른 도로의 종류, 같은 법 제19조제2항 각 호에 따른 노선번호, 노선명, 기점ㆍ종점, 주요 통\n과지\n4. 해당 도로구역의 도로공사 사업 수행 기간(도로구역을 폐지하는 경우는 제외한다)\n \n제5조(도로구간 및 기초번호 설정ㆍ부여의 세부기준) ① 법 제7조제1항에 따라 도로구간을 설정하려는 경우에는 각 도\n로구간을 독립된 도로구간으로 설정하는 것을 원칙으로 한다. 다만, 연장될 가능성이 없는 50미터(읍ㆍ면 지역은\n500미터로 한다) 미만의 도로구간은 별도의 도로구간이 아닌 종속구간으로 설정할 수 있다.\n② 영 제7조제2항제7호다목 단서에서 “시작지점이 연장될 가능성이 있는 경우 등 행정안전부령으로 정하는 경우\n”란 다음 각 호의 어느 하나에 해당하는 경우를 말한다.\n1. 도로의 한쪽 끝이 하천ㆍ강ㆍ바다 등으로 막혀 있어 연장될 가능성이 없는 경우\n2. 길인 도로구간의 시작지점을 지역의 중심축을 이루는 도로의 방향으로 해야 하는 경우\n3. 로(路) 또는 길인 도로구간이 연장될 가능성이 있어 분기점을 시작지점으로 설정해야 하는 경우\n4. 길인 도로구간을 인근에 있는 제2호 또는 제3호의 도로 방향과 일치시키려는 경우\n', metadata={'source': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'file_path': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'page': 0, 'total_pages': 20, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'iText 2.1.7 by 1T3XT', 'creationDate': "D:20240608104118+09'00'", 'modDate': "D:20240608104118+09'00'", 'trapped': ''}),
#  Document(page_content='법제처                                                            2                                                       국가법령정보센터\n도로명주소법 시행규칙\n5. 「섬 발전 촉진법」 제2조에 따른 섬에 위치한 도로의 경우\n6. 영 제3조제1항제2호 및 제3호의 입체도로 및 내부도로에 도로명을 부여하기 위하여 도로구간을 설정하는 경우\n③ 도로구간은 다음 각 호의 방법에 따라 설정한다.\n1. 도로구간의 끝지점에서 새로운 도로구간이 연결되는 경우에는 기초번호가 유지되도록 도로구간의 끝지점을 새\n로 연결되는 도로구간의 끝지점으로 할 것\n2. 도로구간의 시작지점에서 새로운 도로구간이 연결되는 경우에는 기초번호가 유지되도록 다음 각 목의 방법에 따\n라 설정할 것. 다만, 도로명주소의 안정성을 확보할 필요가 있는 경우에는 연장된 도로구간을 별도의 도로구간으\n로 설정할 수 있다.\n가. 새로 연결되는 도로구간이 제1항 단서에 해당하는 경우에는 그 도로구간을 종속구간으로 설정할 것\n나. 새로 연결되는 도로구간이 제1항 단서에 해당하지 않는 경우에는 그 도로구간의 시작지점을 새로 연결되는\n도로구간의 시작지점으로 설정할 것\n3. 도로구간의 시작지점과 끝지점이 아닌 지점에서 도로의 선형(線形)이 변경되는 경우에는 다음 각 목의 방법에 따\n라 설정할 것. 다만, 도로명주소의 안정성을 확보할 필요가 있는 경우에는 연결된 도로구간을 별도의 도로구간으\n로 설정할 수 있다.\n가. 새로 연결되는 부분과 도로구간에서 제외되는 부분이 모두 제1항 단서에 해당하는 경우에는 새로 연결되는\n부분은 기존 도로구간의 종속구간으로 설정할 것\n나. 새로 연결되는 부분과 도로구간에서 제외되는 부분이 모두 제1항 단서에 해당하지 않는 경우에는 새로 연결\n되는 도로구간을 기존 도로구간과 연결하여 하나의 도로구간으로 설정하고, 도로구간에서 제외되는 부분은 별\n도의 도로구간으로 설정할 것\n다. 새로 연결되는 부분이 제1항 단서에 해당하고 도로구간에서 제외되는 부분은 제1항 단서에 해당하지 않는 경\n우 새로 연결되는 부분은 기존 도로구간의 종속구간으로 설정할 것\n라. 새로 연결되는 부분이 제1항 단서에 해당하지 않고 도로구간에서 제외되는 부분은 제1항 단서에 해당하는 경\n우에는 새로 연결되는 부분은 기존의 도로구간과 연결하여 하나의 도로구간으로 설정하고, 도로구간에서 제외\n되는 부분은 종속구간으로 설정할 것\n4. 도로구간의 시작지점 또는 끝지점의 도로가 일부 폐지된 경우에는 현행 기초번호가 유지되도록 시작지점 또는\n끝지점을 변경할 것\n5. 도로구간의 시작지점 또는 끝지점이 아닌 부분에서 도로가 일부 폐지된 경우에는 다음 각 목의 방법에 따라 설정\n할 것. 다만, 도로명주소의 안정성을 확보할 필요가 있는 경우에는 폐지된 도로를 가상의 도로구간으로 유지하거\n나 지역적 특성을 고려하여 각 목과 다르게 설정할 수 있다.\n가. 도로구간의 시작지점이 있는 도로 부분은 도로구간의 기초번호가 유지되도록 끝지점을 변경할 것\n나. 도로구간의 끝지점이 있는 도로 부분은 별도의 도로구간으로 설정할 것\n6. 고속도로, 「도로교통법」 제2조제2호에 따른 자동차전용도로(이하 “자동차전용도로”라 한다) 등에 설치되는 나들\n목 및 입체교차로에서 서로 다른 도로로 이동하는 데 사용되는 도로의 연결구간은 주된 도로구간의 종속구간으\n로 설정할 것. 다만, 해당 도로의 연결구간이 도로시설물 등으로 주된 도로와 분리되지 않는 경우에는 주된구간에\n포함할 수 있다.\n④ 종속구간의 기초번호는 주된 도로구간의 기초번호에 가지번호를 붙여 부여한다. 이 경우 가지번호는 시작지점부\n터 차례로 왼쪽 종속구간은 홀수번호를, 오른쪽 종속구간은 짝수번호를 부여한다.\n \n제6조(도로명 부여의 세부기준) 영 제8조제8항에 따른 도로명 부여의 세부기준은 다음 각 호와 같다.\n1. 영 제3조제1항제1호나목3)에 따른 길에 영 제8조제2항 각 호 외의부분 후단에 따른 숫자나 방위를 붙이려는 경\n우에는 다음 각 목의 어느 하나에 해당하는 방식으로 도로명을 부여할 것\n가. 기초번호방식: 길의 시작지점이 분기되는 도로구간의 도로명, 길이 분기되는 지점의 기초번호와 ‘번길’을 차례\n로 붙여서 도로명을 부여할 것\n', metadata={'source': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'file_path': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'page': 1, 'total_pages': 20, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'iText 2.1.7 by 1T3XT', 'creationDate': "D:20240608104118+09'00'", 'modDate': "D:20240608104118+09'00'", 'trapped': ''}),
#  Document(page_content='법제처                                                            3                                                       국가법령정보센터\n도로명주소법 시행규칙\n나. 일련번호방식: 길의 시작지점이 분기되는 도로구간의 도로명, 길이 분기되는 지점의 일련번호(도로구간에 일\n정한 간격 없이 순차적으로 부여하는 번호를 말한다)와 ‘길’을 차례로 붙여서 도로명을 부여할 것\n다. 복합명사방식: 주된 명사에 방위 등을 붙여 도로명을 부여할 것\n2. 도로구간만 변경된 경우에는 기존의 도로명을 계속 사용할 것\n3. 도로명에 숫자를 사용하는 경우 숫자는 한 번만 사용하도록 할 것\n4. 도로명은 한글로 표기할 것(숫자와 온점을 포함할 수 있다)\n5. 도로명의 로마자 표기는 문화체육관광부장관이 정하여 고시하는 「국어의 로마자 표기법」을 따를 것\n6. 영 제3조제1항제1호나목에 따른 도로의 유형을 안내하는 경우 다음 각 목과 같이 표기할 것\n가. 대로(大路): Blvd\n나. 로(路): St\n다. 길(街): Rd\n \n제7조(둘 이상의 시ㆍ군ㆍ구 또는 시ㆍ도에 걸쳐 있는 도로명 등의 설정ㆍ부여 세부기준) ① 영 제9조제1항에 따라 둘\n이상의 시ㆍ군ㆍ구 또는 시ㆍ도에 걸쳐 있는 도로에 시ㆍ군ㆍ구의 행정구역을 경계로 도로구간을 설정하려는 경우\n그 세부기준은 다음 각 호와 같다. 다만, 제5조제1항 단서에 해당하는 도로구간은 행정구역을 경계로 도로구간을 구\n분하지 않고, 하나의 도로구간으로 설정한다.\n1. 시ㆍ군ㆍ구의 경계가 두 번 이상 교차하는 경우: 교차하는 구역의 중간 지점에 가까운 도로구간과 행정구역 경계\n의 교차점을 기준으로 설정할 것\n2. 도로를 따라 시ㆍ군ㆍ구의 행정구역 경계가 나누어진 경우: 낮은 기초번호의 부여가 예상되는 도로구간과 행정\n구역 경계의 교차점을 기준으로 설정할 것\n3. 두 개의 주된구간을 연결하는 종속구간에 시ㆍ군ㆍ구 행정구역 경계가 있는 경우: 해당 행정구역의 경계를 기준\n으로 설정할 것\n② 영 제9조제2항에 따라 도로구간, 기초번호 및 도로명(이하 “도로명등”이라 한다)을 설정ㆍ부여하는 경우에는 다\n음 각 호의 사항을 도로구간 구분의 기준으로 한다.\n1. 하천, 강, 바다, 다리, 그 밖의 자연적 또는 인공적 지형지물\n2. 고속도로 및 자동차전용도로의 나들목\n3. 특별시ㆍ광역시ㆍ도의 행정구역 경계\n \n제8조(도로명등의 부여ㆍ설정 절차) ① 영 제10조제1항 전단에서 “행정안전부령으로 정하는 사항”이란 다음 각 호의\n사항을 말한다.\n1. 영 제7조제1항 각 호의 사항\n2. 영 제7조제4항 및 제5항에 따른 도로구간의 시작지점과 끝지점의 기초번호 및 기초간격\n3. 도로의 길이와 폭\n4. 예비도로명과 그 부여 사유\n5. 의견 제출의 기간 및 방법\n6. 도로명의 부여 절차\n7. 그 밖에 특별자치시장ㆍ특별자치도지사 및 시장ㆍ군수ㆍ구청장(이하 “시장등”이라 한다)이 필요하다고 인정하는\n사항\n② 영 제10조제2항에서 “행정안전부령으로 정하는 사항”이란 다음 각 호의 사항을 말한다.\n1. 제1항제1호부터 제4호까지의 사항\n2. 도로명 부여에 대한 해당 지역주민과 시장등의 의견\n3. 그 밖에 시장등이 필요하다고 인정하는 사항\n③ 시장등은 영 제10조제3항 후단에 따라 제12조제1항 각 호의 사항을 고시해야 한다.\n \n', metadata={'source': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'file_path': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'page': 2, 'total_pages': 20, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'iText 2.1.7 by 1T3XT', 'creationDate': "D:20240608104118+09'00'", 'modDate': "D:20240608104118+09'00'", 'trapped': ''})]

# %%
len(pages[0].page_content)
# Out:
# 1939

# %%
import chromadb
import uuid
from tqdm import tqdm
from langchain.text_splitter import RecursiveCharacterTextSplitter
from chromadb.utils import embedding_functions
from chromadb.utils.embedding_functions import OllamaEmbeddingFunction

def insert(content):
    # client = chromadb.Client()
    # client = chromadb.HttpClient(host="localhost", port=8000)
    # openai_ef = embedding_functions.OpenAIEmbeddingFunction(
    #             model_name="text-embedding-ada-002"
    #         )
    ollama_ef = OllamaEmbeddingFunction(url="http://localhost:11434/api/embeddings", model_name="llama3")
    collection = client.get_collection(name="test", embedding_function=ollama_ef)

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=200)
    docs = text_splitter.split_documents(content)

    for doc in tqdm(docs):
        uuid_val = uuid.uuid1()
        # print("Inserted documents for ", uuid_val)
        collection.add(ids=[str(uuid_val)], documents=doc.page_content, metadatas=doc.metadata)

# %%
insert(pages)
# Out:
# 100%|██████████| 18/18 [00:14<00:00,  1.27it/s]

# %% [markdown]
# * gemma: 18분 (전체 문서 기준)
# * eeve: (빠름)
# * llama3:bllossom:
# * llama3: 14초
# * llama3:70b:

# %%
import chromadb
from langchain.vectorstores import Chroma
# from langchain.embeddings.openai import OpenAIEmbeddings
from langchain_community.embeddings import OllamaEmbeddings

def queryDB(query):
    # client = chromadb.HttpClient(host="localhost", port=8000)
    # embedding_function = OpenAIEmbeddings()
    embedding_function = OllamaEmbeddings(model="llama3")
    db4 = Chroma(client=client, collection_name="test", embedding_function=embedding_function)
    docs = db4.similarity_search_with_score(query) ## 유사도 점수까지 확인: https://wikidocs.net/234094
    # retriever = db4.as_retriever(search_type="mmr") ## mmr 검색
    
    return docs # retriever.get_relevant_documents(query)[0]

# %%
query="도로명관할구역에 대해서 설명해줘"
result = queryDB(query)
result
# Out:
# [(Document(page_content='되는 도로구간을 기존 도로구간과 연결하여 하나의 도로구간으로 설정하고, 도로구간에서 제외되는 부분은 별\n도의 도로구간으로 설정할 것\n다. 새로 연결되는 부분이 제1항 단서에 해당하고 도로구간에서 제외되는 부분은 제1항 단서에 해당하지 않는 경\n우 새로 연결되는 부분은 기존 도로구간의 종속구간으로 설정할 것\n라. 새로 연결되는 부분이 제1항 단서에 해당하지 않고 도로구간에서 제외되는 부분은 제1항 단서에 해당하는 경\n우에는 새로 연결되는 부분은 기존의 도로구간과 연결하여 하나의 도로구간으로 설정하고, 도로구간에서 제외\n되는 부분은 종속구간으로 설정할 것\n4. 도로구간의 시작지점 또는 끝지점의 도로가 일부 폐지된 경우에는 현행 기초번호가 유지되도록 시작지점 또는\n끝지점을 변경할 것\n5. 도로구간의 시작지점 또는 끝지점이 아닌 부분에서 도로가 일부 폐지된 경우에는 다음 각 목의 방법에 따라 설정', metadata={'author': '', 'creationDate': "D:20240608104118+09'00'", 'creator': '', 'file_path': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'format': 'PDF 1.4', 'keywords': '', 'modDate': "D:20240608104118+09'00'", 'page': 1, 'producer': 'iText 2.1.7 by 1T3XT', 'source': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}),
#   31332.407036957564),
#  (Document(page_content='지 않은 지역에서는 영 제6조제2항제1호가목 및 제2호나목에 따른 사업지역의 명칭을 말한다.\n \n제3조(기초번호의 부여 간격) 「도로명주소법」(이하 “법”이라 한다) 제2조제4호에서 “행정안전부령으로 정하는 간격”이\n란 20미터를 말한다. 다만, 다음 각 호의 도로에 대하여는 다음 각 호의 간격으로 한다.\n1. 「도로교통법」 제2조제3호에 따른 고속도로(이하 “고속도로”라 한다): 2킬로미터\n2. 건물번호의 가지번호가 두 자리 숫자 이상으로 부여될 수 있는 길 또는 해당 도로구간에서 분기되는 도로구간이\n없고, 가지번호를 이용한 건물번호를 부여하기 곤란한 길: 10미터\n3. 가지번호를 이용하여 건물번호를 부여하기 곤란한 종속구간: 10미터 이하의 일정한 간격\n4. 영 제3조제1항제3호에 따른 내부도로: 20미터 또는 도로명주소 및 사물주소의 부여 개수를 고려하여 정하는 간\n격', metadata={'author': '', 'creationDate': "D:20240608104118+09'00'", 'creator': '', 'file_path': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'format': 'PDF 1.4', 'keywords': '', 'modDate': "D:20240608104118+09'00'", 'page': 0, 'producer': 'iText 2.1.7 by 1T3XT', 'source': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}),
#   32295.711246833667),
#  (Document(page_content='터 차례로 왼쪽 종속구간은 홀수번호를, 오른쪽 종속구간은 짝수번호를 부여한다.\n \n제6조(도로명 부여의 세부기준) 영 제8조제8항에 따른 도로명 부여의 세부기준은 다음 각 호와 같다.\n1. 영 제3조제1항제1호나목3)에 따른 길에 영 제8조제2항 각 호 외의부분 후단에 따른 숫자나 방위를 붙이려는 경\n우에는 다음 각 목의 어느 하나에 해당하는 방식으로 도로명을 부여할 것\n가. 기초번호방식: 길의 시작지점이 분기되는 도로구간의 도로명, 길이 분기되는 지점의 기초번호와 ‘번길’을 차례\n로 붙여서 도로명을 부여할 것', metadata={'author': '', 'creationDate': "D:20240608104118+09'00'", 'creator': '', 'file_path': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'format': 'PDF 1.4', 'keywords': '', 'modDate': "D:20240608104118+09'00'", 'page': 1, 'producer': 'iText 2.1.7 by 1T3XT', 'source': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}),
#   32847.42675476938),
#  (Document(page_content='제5조(도로구간 및 기초번호 설정ㆍ부여의 세부기준) ① 법 제7조제1항에 따라 도로구간을 설정하려는 경우에는 각 도\n로구간을 독립된 도로구간으로 설정하는 것을 원칙으로 한다. 다만, 연장될 가능성이 없는 50미터(읍ㆍ면 지역은\n500미터로 한다) 미만의 도로구간은 별도의 도로구간이 아닌 종속구간으로 설정할 수 있다.\n② 영 제7조제2항제7호다목 단서에서 “시작지점이 연장될 가능성이 있는 경우 등 행정안전부령으로 정하는 경우\n”란 다음 각 호의 어느 하나에 해당하는 경우를 말한다.\n1. 도로의 한쪽 끝이 하천ㆍ강ㆍ바다 등으로 막혀 있어 연장될 가능성이 없는 경우\n2. 길인 도로구간의 시작지점을 지역의 중심축을 이루는 도로의 방향으로 해야 하는 경우\n3. 로(路) 또는 길인 도로구간이 연장될 가능성이 있어 분기점을 시작지점으로 설정해야 하는 경우\n4. 길인 도로구간을 인근에 있는 제2호 또는 제3호의 도로 방향과 일치시키려는 경우', metadata={'author': '', 'creationDate': "D:20240608104118+09'00'", 'creator': '', 'file_path': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'format': 'PDF 1.4', 'keywords': '', 'modDate': "D:20240608104118+09'00'", 'page': 0, 'producer': 'iText 2.1.7 by 1T3XT', 'source': '../data/도로명주소법 시행규칙(행정안전부령)(제00324호)(20220330).pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}),
#   33225.7789898531)]

# %%
max_similarity_doc = min(result, key=lambda x: x[1])[0].page_content
max_similarity_doc
# Out:
# '시군구의 주소정보 전산체계 관리책임자는 보안관리를 위하여 관계공\n·\n, \n·\n·\n○ \n무원을 보안담당자로 지정하고 주기적으로 보안점검을 실시하고 미흡한 부분\n을 보완하여야 함'

# %%
import ollama

output = ollama.generate(
    model="llama3",
    prompt=f"Using the data: {max_similarity_doc}. Respond to this prompt: {query}. If data doesn't have an appropriate value to answer the question in the prompt, answer 'I can't answer the question.' 한국어로 대답해줘 "
)

print(output['response'])
# Out:
# 제공된 데이터에는 사물주소에 대한 정보가 포함되어 있지 않습니다. 따라서 이 질문에 답할 수 없습니다.

# %% [markdown]
# ## OpenAI API
# * 어느 정도 나오기는 한데, retrieval한 결과를 기반으로 답변하는 것 같지가 않음. chunk size를 바꿔서 테스트 해볼 필요 있음

# %%
pip install langchain_core
# Out:
# Requirement already satisfied: langchain_core in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from langchain_core) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.66 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from langchain_core) (0.1.71)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from langchain_core) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from langchain_core) (2.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from langchain_core) (8.2.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.66->langchain_core) (3.10.2)
# Requirement already satisfied: requests<3,>=2 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.66->langchain_core) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from pydantic<3,>=1->langchain_core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from pydantic<3,>=1->langchain_core) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from pydantic<3,>=1->langchain_core) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.66->langchain_core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.66->langchain_core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.66->langchain_core) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cauhike/Documents/GitHub/chroma/env/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.66->langchain_core) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ
#    -0.00553325517103076,
#    0.006710543762892485,
#    -0.02343812957406044,
#    0.00817374512553215,
#    -0.0072184596210718155,
#    -0.006626451853662729,
#    -0.004386240150779486,
#    0.026438534259796143,
#    0.023599587380886078,
#    0.02825492061674595,
#    -0.035170648247003555,
#    -0.004278602544218302,
#    0.02102973498404026,
#    0.014248552732169628,
#    0.0033401353284716606,
#    -0.0031971789430826902,
#    0.03726958483457565,
#    -0.017518050968647003,
#    0.00514643220230937,
#    0.014921288937330246,
#    -0.021823562681674957,
#    -0.03108041360974312,
#    -0.018110059201717377,
#    -0.013622908852994442,
#    -0.004551060497760773,
#    0.01792169362306595,
#    ...]],
#  'metadatas': [None, None, None, None, None, None, None, None, None, None],
#  'documents': ["국가주소정보시스템 중앙운영지원 및 기능보강사업 추진(‘12.6.~'12.12.)\n• \n- 위치 찾기 선진화고시 시스템지점기초구역 등및 상세주소 관리시스템\n \n(\n, \n) \n개발\n \n도로명주소기본도 위치정확도 개선사업(’12.6.~’13.12.)\n• \n• 국가주소정보시스템 유지관리 및 체계 개편 추진('13.1.~’13.12.)",
#   'Gold thema-ro\nChina town-gil\n6) 도로명의 주된 명사가 외국어영문\n약어로 이루어진 때 외국어영문약어는 모두 대문자\n(\n) \n(\n)\n로 하며줄임말로 이루어진 때에는 첫 글자만 대문자로 하고 나머지는 소문자로 한다\n, \n.\n엘씨디로\n유엔로\nLCD-ro\nUN-ro\n7) 인명\n회사명',
#   '제장 주소정보의 개요\nI\n ■  ■  ■\n69\n도로명주소 전면시행 대응 및 정보시스템 유지관리(‘14.4.~’14.12.)\n• \n국가주소정보시스템 유지관리(‘14.4.~’14.12.)\n• \n도로명주소 안내홈페이지 및 주소 찾아앱\n개편\n- \n(\n) \n(’14.4.~‘14.8.)\n웹접근성 품질인증마크 취득\n- \n(’14.12.)\n년 국가주소정보시스템 유지관리',
#   ', \n.\n엘씨디로\n유엔로\nLCD-ro\nUN-ro\n7) 인명\n회사명\n단체명을 도로명의 주된 명사로 사용할 때 인명이나 그 회사\n단체에서 \n, \n, \n, \n사용하는 특정 고유명사에 대한 로마자 표기가 있을 때에는 그 표기대로 쓸 수 있다.\n안의 표기를 허용함\n((   )\n)\n이순신로\n이동녕로\n삼성로\n이화여대길\n연세길\n계원대학로\n농심길\nIsunsin-ro',
#   '웹접근성 품질인증마크 취득\n- \n(’14.12.)\n년 국가주소정보시스템 유지관리\n2015\n(’15.1.~’15.12.)\n• \n국가기초구역번호를 활용한 새 우편번호 시행 지원\n- \n(’15.8)\n웹접근성 품질인증마크 갱신\n- \n(‘15.12.)\n년 국가주소정보시스템 유지관리\n2016\n(’16.1.~’16.12.)\n•',
#   ')\n이순신로\n이동녕로\n삼성로\n이화여대길\n연세길\n계원대학로\n농심길\nIsunsin-ro\n(Yisunsin-ro)\nIdongnyeong-ro\n(Leedongnyeong-ro)\nSamseong-ro\n(Samsung-ro)\nIwhayeodae-ro\n(Ewhayeodae-gil)\nYeonse-gil\n(Yonsei-gil)\nGyewondaehak-ro',
#   '년 국가주소정보시스템 유지관리\n2016\n(’16.1.~’16.12.)\n• \n공공민간 웹사이트 주소 활용점검 및 후속 조치\n연중\n- \n·\n(’16. \n)\n도로명주소 개발자센터 구축\n- \n(‘16.7.)\n사용자 중심의 도로명주소 안내홈페이지 개편\n- \n(‘16.10.)\n년 국가주소정보시스템 유지관리\n2017\n(‘17.1.~’17.12.)\n•',
#   'Yeonse-gil\n(Yonsei-gil)\nGyewondaehak-ro\n(Kyewondaehak-ro)\nNongsim-gil\n(Nongshim-gil)',
#   '년 국가주소정보시스템 유지관리\n2017\n(‘17.1.~’17.12.)\n• \n도로명주소 홈페이지 대민 통계서비스 개시\n- \n(’17.8.)\n공공민간 웹사이트 주소 활용점검 및 후속 조치\n연중\n- \n·\n(’17. \n)\n리뉴얼\n- KAIS WEB \n(’17.9.)\n스마트 \n전국 확대 보급\n- \nKAIS \n(’17.11.)\n웹접근성 품질인증마크 갱신\n-',
#   '■  ■  ■\n주소정보 업무편람\n456\n8) 기관명을 도로명의 주된 명사로 사용할 때에는 기관명의 영어 번역어를 사용하지 않고 \n우리말의 소리 나는 대로 표기한다.\n대원여고길\n풍납복지관길\n시청길\nDaewonyeogo-gil\nPungnapbokjigwan-gil\nSicheong-gil'],
#  'data': None,
#  'uris': None}

# %%
import chromadb
import uuid
from tqdm import tqdm
from langchain.text_splitter import RecursiveCharacterTextSplitter
from chromadb.utils import embedding_functions
from chromadb.utils.embedding_functions import OllamaEmbeddingFunction

def insert(content):
    # client = chromadb.Client()
    client = chromadb.HttpClient(host="localhost", port=8000)
    openai_ef = embedding_functions.OpenAIEmbeddingFunction(
                model_name="text-embedding-ada-002"
            )
    # ollama_ef = OllamaEmbeddingFunction(url="http://localhost:11434/api/embeddings", model_name="gemma")
    collection = client.get_collection(name="address_business_guide_openai", embedding_function=openai_ef)

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=50)
    docs = text_splitter.split_documents(content)

    for doc in tqdm(docs):
        uuid_val = uuid.uuid1()
        # print("Inserted documents for ", uuid_val)
        collection.add(ids=[str(uuid_val)], documents=doc.page_content)

# %%
insert(pages)
# Out:
# 100%|██████████| 2383/2383 [12:01<00:00,  3.30it/s]

# %% [markdown]
# - 시간: 12분
# - 차감 금액: 0.06달러

# %%
import chromadb
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
# from langchain_community.embeddings import OllamaEmbeddings

def queryDB(query):
    client = chromadb.HttpClient(host="localhost", port=8000)
    embedding_function = OpenAIEmbeddings()
    # embedding_function = OllamaEmbeddings(model="gemma")
    db4 = Chroma(client=client, collection_name="address_business_guide_openai", embedding_function=embedding_function)
    docs = db4.similarity_search_with_score(query) ## 유사도 점수까지 확인: https://wikidocs.net/234094
    # retriever = db4.as_retriever(search_type="mmr") ## mmr 검색
    
    return docs # retriever.get_relevant_documents(query)[0]
# Out:
# /Users/cauhike/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
query="사물주소에 대해서 설명해줘"
result = queryDB(query)
result

# %%
max_similarity_doc = min(result, key=lambda x: x[1])[0].page_content
max_similarity_doc
# Out:
# '대체주소는 도로명주소가 부여된 건물등의 별도의 출입구 또는 사물주소가 부여된 \n○ \n시설물의 별도의 기준점에 부여된 주소정보를 말함\n2) 별칭\n○ 참조체계에 따라 작성된 주소정보의 구성요소가 아니라 상호\n건물명\n시설물명 \n, \n, \n등과 같이 해당 객체를 부를 때 사용되는 여러 명칭을 말함\n3) 시간정보'

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

# 프롬프트 생성
prompt = f"""Answer the question based only on the following context, which can include texts:
{max_similarity_doc}
If you can't find the answer in the context, answer "I can't answer the question.".
Please answer in Korean.
"""

# LLM
model = ChatOpenAI(temperature=0, model="gpt-4o")

# RAG pipeline
chain = (
    RunnablePassthrough(lambda x: prompt)  # 함수를 직접 전달
    | model
    | StrOutputParser()
)

# 파이프라인 실행
output = chain.invoke(query)
print(output)
# Out:
# 사물주소는 사물인터넷(IoT) 기술을 활용하여 물리적인 사물에 고유한 디지털 주소를 부여하는 개념입니다. 이를 통해 사물들은 인터넷을 통해 서로 소통하고 데이터를 주고받을 수 있습니다. 사물주소는 주로 다음과 같은 요소들로 구성됩니다:
#
# 1. **고유 식별자(UID)**: 각 사물에 부여되는 고유한 식별 번호입니다. 이 번호를 통해 특정 사물을 다른 사물과 구분할 수 있습니다.
#
# 2. **네트워크 주소**: 사물이 인터넷에 연결될 수 있도록 IP 주소나 MAC 주소와 같은 네트워크 주소가 필요합니다.
#
# 3. **메타데이터**: 사물의 상태, 위치, 기능 등을 설명하는 추가 정보입니다. 예를 들어, 온도 센서라면 현재 온도, 위치, 배터리 상태 등의 정보가 포함될 수 있습니다.
#
# 사물주소는 다양한 응용 분야에서 활용될 수 있습니다. 예를 들어, 스마트 홈에서는 가전제품들이 서로 소통하여 효율적으로 에너지를 관리할 수 있고, 스마트 시티에서는 교통 신호등, 가로등, 쓰레기통 등이 서로 연결되어 도시의 효율성을 높일 수 있습니다.
#
# 사물주소의 주요 장점은 다음과 같습니다:
#
# - **효율성 향상**: 사물들이 서로 소통함으로써 자원을 효율적으로 사용할 수 있습니다.
# - **자동화**: 많은 작업이 자동화되어 인간의 개입이 줄어듭니다.
# - **데이터 수집 및 분석**: 다양한 사물에서 데이터를 수집하여 분석함으로써 더 나은 의사결정을 할 수 있습니다.
#
# 하지만 사물주소를 구현하는 데에는 보안 문제, 표준화 문제, 데이터 프라이버시 문제 등 여러 도전 과제도 존재합니다. 이러한 문제들을 해결하기 위해 다양한 연구와 기술 개발이 진행되고 있습니다.

# %%
## 한번에 실행하는 코드

from langchain_openai import ChatOpenAI

query="사물주소 부여 원칙에 대해서 설명해줘"
result = queryDB(query)
max_similarity_doc = min(result, key=lambda x: x[1])[0].page_content


# 프롬프트 생성
prompt = f"""Answer the question based only on the following context, which can include texts:
{max_similarity_doc}
If you can't find the answer in the context, answer "I can't answer the question.".
Please answer in Korean.
"""

# LLM
model = ChatOpenAI(temperature=0, model="gpt-4o")

# RAG pipeline
chain = (
    RunnablePassthrough(lambda x: prompt)  # 함수를 직접 전달
    | mod
    | StrOutputParser()
)

# 파이프라인 실행
output = chain.invoke(query)
print(max_similarity_doc)
print('========================')
print(output)
# Out:
# 제
# 장 주소정보 부여변경폐지
# III
# ·
# ·
#  ■  ■  ■
# 243
# 2
# 사물주소의 부여변경폐지 기준
# ·
# ·
# 가
# 사물주소의 부여변경폐지 기준
# .
# ·
# ·
# 사물주소 부여 원칙영
# 1)
# (
# §41
# )
# ①
# 행정안전부장관이 고시한 사물주소 부여 대상 시설물시설 및 장소마다  하나의
# (
# )
# ○
# 사물번호 부여
# ========================
# 사물주소 부여 원칙은 사물인터넷(IoT) 환경에서 각 사물에 고유한 주소를 부여하여 네트워크 상에서 식별하고 통신할 수 있도록 하는 원칙을 의미합니다. 이 원칙은 사물인터넷의 효율적 운영과 관리에 필수적입니다. 주요 원칙은 다음과 같습니다:
#
# 1. **고유성 (Uniqueness)**:
#    - 각 사물에 부여되는 주소는 전 세계적으로 유일해야 합니다. 이는 충돌을 방지하고, 각 사물을 명확하게 식별할 수 있도록 합니다.
#
# 2. **확장성 (Scalability)**:
#    - 사물의 수가 기하급수적으로 증가할 것을 대비하여, 주소 체계는 확장 가능해야 합니다. IPv6와 같은 주소 체계는 이러한 확장성을 제공합니다.
#
# 3. **유연성 (Flexibility)**:
#    - 다양한 종류의 사물과 다양한 네트워크 환경에서 사용될 수 있도록 주소 체계는 유연해야 합니다. 이는 다양한 프로토콜과의 호환성을 의미합니다.
#
# 4. **관리 용이성 (Manageability)**:
#    - 주소 체계는 관리가 용이해야 합니다. 이는 주소의 할당, 변경, 해제 등이 효율적으로 이루어질 수 있어야 함을 의미합니다.
#
# 5. **보안성 (Security)**:
#    - 사물 주소는 보안성을 갖추어야 합니다. 이는 주소의 위조나 변조를 방지하고, 사물 간의 안전한 통신을 보장하기 위함입니다.
#
# 6. **표준화 (Standardization)**:
#    - 주소 체계는 국제적으로 표준화되어야 합니다. 이는 다양한 제조업체와 서비스 제공자가 동일한 기준을 따를 수 있도록 하여 상호 운용성을 보장합니다.
#
# 7. **지속 가능성 (Sustainability)**:
#    - 주소 체계는 장기적으로 지속 가능해야 합니다. 이는 기술의 발전과 환경 변화에 따라 유연하게 대응할 수 있어야 함을 의미합니다.
#
# 이러한 원칙들은 사물인터넷 환경에서 각 사물이 원활하게 통신하고, 관리되며, 보안이 유지될 수 있도록 하는 데 중요한 역할을 합니다.

# %% [markdown]
# ## Ollama(llama3:70b)

# %%
collection = chroma_client.create_collection(name="address_business_guide_llama3")
collection.peek()
# Out:
# {'ids': [],
#  'embeddings': [],
#  'metadatas': [],
#  'documents': [],
#  'data': None,
#  'uris': None}

# %%
import chromadb
import uuid
from tqdm import tqdm
from langchain.text_splitter import RecursiveCharacterTextSplitter
from chromadb.utils import embedding_functions
from chromadb.utils.embedding_functions import OllamaEmbeddingFunction

def insert(content):
    # client = chromadb.Client()
    client = chromadb.HttpClient(host="localhost", port=8000)
    # openai_ef = embedding_functions.OpenAIEmbeddingFunction(
    #             model_name="text-embedding-ada-002"
    #         )
    ollama_ef = OllamaEmbeddingFunction(url="http://localhost:11434/api/embeddings", model_name="llama3:70b")
    collection = client.get_collection(name="address_business_guide_llama3", embedding_function=ollama_ef)

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=10)
    docs = text_splitter.split_documents(content)

    for doc in tqdm(docs):
        uuid_val = uuid.uuid1()
        # print("Inserted documents for ", uuid_val)
        collection.add(ids=[str(uuid_val)], documents=doc.page_content)

# %%
insert(pages)
# Out:
#  12%|█▏        | 140/1126 [4:49:02<33:55:41, 123.88s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 insert(pages)
#
# Cell In[18], line 24, in insert(content)
#      22 uuid_val = uuid.uuid1()
#      23 # print("Inserted documents for ", uuid_val)
# ---> 24 collection.add(ids=[str(uuid_val)], documents=doc.page_content)
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/chromadb/api/models/Collection.py:154, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#     151 if embeddings is None:
#     152     # At this point, we know that one of documents or images are provided from the validation above
#     153     if documents is not None:
# --> 154         embeddings = self._embed(input=documents)
#     155     elif images is not None:
#     156         embeddings = self._embed(input=images)
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/chromadb/api/models/Collection.py:633, in Collection._embed(self, input)
#     628 if self._embedding_function is None:
#     629     raise ValueError(
#     630         "You must provide an embedding function to compute embeddings."
#     631         "https://docs.trychroma.com/embeddings"
#     632     )
# --> 633 return self._embedding_function(input=input)
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/chromadb/api/types.py:193, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     192 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 193     result = call(self, input)
#     194     return validate_embeddings(maybe_cast_one_to_many_embedding(result))
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/chromadb/utils/embedding_functions.py:1006, in OllamaEmbeddingFunction.__call__(self, input)
#    1004 # Call Ollama Server API for each document
#    1005 texts = input if isinstance(input, list) else [input]
# -> 1006 embeddings = [
#    1007     self._session.post(
#    1008         self._api_url, json={"model": self._model_name, "prompt": text}
#    1009     ).json()
#    1010     for text in texts
#    1011 ]
#    1012 return cast(
#    1013     Embeddings,
#    1014     [
#    (...)
#    1018     ],
#    1019 )
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/chromadb/utils/embedding_functions.py:1007, in <listcomp>(.0)
#    1004 # Call Ollama Server API for each document
#    1005 texts = input if isinstance(input, list) else [input]
#    1006 embeddings = [
# -> 1007     self._session.post(
#    1008         self._api_url, json={"model": self._model_name, "prompt": text}
#    1009     ).json()
#    1010     for text in texts
#    1011 ]
#    1012 return cast(
#    1013     Embeddings,
#    1014     [
#    (...)
#    1018     ],
#    1019 )
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/GitHub/chroma/env/lib/python3.9/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# * 시간: 5시간 동안 12% 돌아감. 이건 못 쓸듯!

# %%
import chromadb
from langchain.vectorstores import Chroma
# from langchain.embeddings.openai import OpenAIEmbeddings
from langchain_community.embeddings import OllamaEmbeddings

def queryDB(query):
    client = chromadb.HttpClient(host="localhost", port=8000)
    # embedding_function = OpenAIEmbeddings()
    embedding_function = OllamaEmbeddings(model="llama3:70b")
    db4 = Chroma(client=client, collection_name="address_business_guide_llama3", embedding_function=embedding_function)
    docs = db4.similarity_search_with_score(query) ## 유사도 점수까지 확인: https://wikidocs.net/234094
    # retriever = db4.as_retriever(search_type="mmr") ## mmr 검색
    
    return docs # retriever.get_relevant_documents(query)[0]

# %%
query="사물주소에 대해서 설명해줘"
result = queryDB(query)
result
